# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here

import requests
import pandas as pd

username = 'katja-galyuk'
token = 'xxx'

response = requests.get('https://api.github.com/user/repos', auth=(username,token))
data = pd.DataFrame(response.json())
data
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/Katja-Galyuk/data...     False
# 1  https://api.github.com/repos/Katja-Galyuk/data...     False
# 2  https://api.github.com/repos/Katja-Galyuk/firs...     False
# 3  https://api.github.com/repos/Katja-Galyuk/mini...     False
# 4  https://api.github.com/repos/Katja-Galyuk/para...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/Katja-Galyuk/data...
# 1  https://api.github.com/repos/Katja-Galyuk/data...
# 2  https://api.github.com/repos/Katja-Galyuk/firs...
# 3  https://api.github.com/repos/Katja-Galyuk/mini...
# 4  https://api.github.com/repos/Katja-Galyuk/para...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/Katja-Galyuk/data...
# 1  https://api.github.com/repos/Katja-Galyuk/data...
# 2  https://api.github.com/repos/Katja-Galyuk/firs...
# ...

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/datav2-labs/commits', auth=(username,token))
data2 = pd.DataFrame(response.json())
data2.head()
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/ta-data-lis/dataV...     False
# 1  https://api.github.com/repos/pmoreira1/dataV2-...     False
# 2  https://api.github.com/repos/mazzoal/dataV2-la...     False
# 3  https://api.github.com/repos/c-cle/dataV2-labs...     False
# 4  https://api.github.com/repos/ReneRaube/dataV2-...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/ta-data-lis/dataV...
# 1  https://api.github.com/repos/pmoreira1/dataV2-...
# 2  https://api.github.com/repos/mazzoal/dataV2-la...
# 3  https://api.github.com/repos/c-cle/dataV2-labs...
# 4  https://api.github.com/repos/ReneRaube/dataV2-...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/ta-data-lis/dataV...
# 1  https://api.github.com/repos/pmoreira1/dataV2-...
# 2  https://api.github.com/repos/mazzoal/dataV2-la...
# ...

# %%
# your code here
for col in data2.columns:
    print(col)
# Out:
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# permissions
# private
# pulls_url
# pushed_at
# releases_url
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# trees_url
# updated_at
# url
# watchers
# watchers_count

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here
languages  = data2["language"].tolist()
list(set(languages))
# Out:
# ['Jupyter Notebook', None]

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

response = requests.get('https://api.github.com/repos/ironhack-datalabs/datav2-labs/commits?since=2020-02-01T00:00:00Z&until2020-03-31T23:59:59Z’', auth=(username,token))
data3 = pd.DataFrame(response.json())
data3
# Out:
#                                               author  \
# 0  {'login': 'kelsey-ironhack', 'id': 52278191, '...
# 1  {'login': 'kelsey-ironhack', 'id': 52278191, '...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
#
#                                               commit  \
# 0  {'author': {'name': 'kelsey-ironhack', 'email'...
# 1  {'author': {'name': 'kelsey-ironhack', 'email'...
#
#                                            committer  \
# 0  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 1  {'login': 'web-flow', 'id': 19864447, 'node_id...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/dataV2-la...
# 1  https://github.com/ironhack-datalabs/dataV2-la...
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjEzNjQxMTcwOjY4MGE5Y2ExY2ViZDc3Mz...
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
commits  = data3["commit"].tolist()
print(commits)
# Out:
# author
# comments_url
# commit
# committer
# html_url
# node_id
# parents
# sha
# url

# %%
# your code here
commits  = data3["commit"].tolist()
print(len(commits))
# Out:
# 2

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
