# %% [markdown]
# Now we want to enhance the `get_bow_from_docs` function so that it will work with HTML webpages. In HTML, there are a lot of messy codes such as HTML tags, Javascripts, [unicodes](https://www.w3schools.com/charsets/ref_utf_misc_symbols.asp) that will mess up your bag of words. We need to clean up those junk before generating BoW.
#
# Next, what you will do is to define several new functions each of which is specialized to clean up the HTML codes in one aspect. For instance, you can have a `strip_html_tags` function to remove all HTML tags, a `remove_punctuation` function to remove all punctuation, a `to_lower_case` function to convert string to lowercase, and a `remove_unicode` function to remove all unicodes.
#
# Then in your `get_bow_from_doc` function, you will call each of those functions you created to clean up the HTML before you generate the corpus.
#
# Note: Please use Python string operations and regular expression only in this lab. Do not use extra libraries such as `beautifulsoup` because otherwise you loose the purpose of practicing.

# %%
import re
from sklearn.feature_extraction import stop_words

# %%
# Define your string handling functions below
# Minimal 3 functions
import re

def remove_unicode(string):  
    return re.sub('(&.*?);','',string)

def strip_html_tags(string):
    return re.sub('<.*?>','',string)

def to_lower_no_punctuation(string):
    if isinstance(string,str):
        string = string.split()
    
    return [re.sub('\W','',w).lower() for w in string]

# %% [markdown]
# Next, paste your previously written `get_bow_from_docs` function below. Call your functions above at the appropriate place.

# %%
def get_bow_from_docs(docs, stop_words=[]):
    # In the function, first define the variables you will use such as `corpus`, `bag_of_words`, and `term_freq`.
    corpus = []
    bag_of_words = []
    term_freq = []
    clean_docs = []
    # write your codes here
    for d in docs:        
        d_content = open(d, "r").read()
        clean_html = strip_html_tags(d_content)
        clean_unicode = remove_unicode(clean_html)
        clean = to_lower_no_punctuation(clean_unicode)
        clean_docs.append(clean)
        
    corpus = [w for s in clean_docs for w in s]
    bag_of_words = list(set(corpus) - set(stop_words))

    for d in docs:
        clean_words = [re.sub('\W','',s).lower() for s in d.split()]
        word_count = []
        for w in bag_of_words:
            word_count.append(clean_words.count(w)) 
        term_freq.append(word_count)
    return {
        "bag_of_words": bag_of_words,
        "term_freq": term_freq
    }

# %% [markdown]
# Next, read the content from the three HTML webpages in the `your-codes` directory to test your function.

# %%
from sklearn.feature_extraction import stop_words
bow = get_bow_from_docs([
        'www.coursereport.com_ironhack.html',
        'en.wikipedia.org_Data_analysis.html',
        'www.lipsum.com.html'
    ],
    stop_words.ENGLISH_STOP_WORDS
)

print(bow)
# Out:
# {'bag_of_words': ['', 'jonathan', 'userexperience', 'similique', 'ability', 'organizing', 'graduation', 'areas', 'favorite', 'iusto', '30459', 'statistical', 'dojouniversity', 'potentialsmorselongrange', 'miamis', '2001', 'sortdefault', '20112020', 's', 'inappropriateironhackgreat', 'users', 'remaining', 'coffee', 'comedies', 'generalized', 'belongs', 'employer', 'procedia', 'various', 'mb', 'stack', 'loved', 'mece', 'decisionoverall', 'presents', 'languages', 'proposition', 'nonresponse', 'consulting', 'eggleston1012014ironhack', 'known', 'codecombat', 'think', 'alan', 'generalizes', 'consistency', 'scheduledcostnaclass', 'tuesdays', 'wont', 'wikiversity', 'ordinal', 'voluptates', '20181023205918', 'familiar', 'median', 'aperiam', 'custodians', 'uncover', 'agile', 'possibly', 'attack', 'editing', 'added', 'remove', 'opens', 'topping', 'dev10252018ricardo', 'anemailgreat', 'suited', 'morning', 'enwikipcacheidhash27209540canonical', 'computers10162018eran', 'realworld', 'standards', 'viewscholarships', 'standard', 'cern', 'led', 'look', 'communities', 'engineering', 'gross', 'tas', 'fast', '83', '023010000', 'announcements', 'githubfun', 'schoolguild', 'automwparseroutput', 'luisa', 'scholarshipscoursereportcom', 'roots', 'reactorrithm', 'plunge', 'bayes', 'depend', 'bootcampsbest', 'analyses', 'recommendation', 'report2017', 'aggregate', 'trademark', 'fight', 'joana', 'la', 'colours', 'marketing', 'began', 'expand', 'rate', 'd', 'sat', 'quidem', 'gap', '1240', 'owing', 'touch', 'lost', 'growth', 'schools', 'friday', 'encyclopedia', 'adversely', 'assistancebefore', 'firehose', 'gift', 'happier', 'inappropriateironhackan', 'apis', 'facets', 'consumption', 'perfectly', 'ironhack', 'scrubbing', 'existing', 'entrepreneurship', 'crispe8132018ironhack', 'carolinas', 'isbn053498052x', 'usual', 'bg', 'ancova', 'avoids', 'againshare', 'pandas', '14emmwparseroutput', 'inappropriateironhackawesome', 'moment', 'functions', 'dynamicsfinite', 'mccleland', 'efforts', 'help', 'random', 'elevatorwyncodezip', 'infancy', '167305', 'onyouve', 'formula', 'rico', 'distinguish', 'detailscampusselect', 'report', 'academymetiscode', 'insightoctober', 'moderately', 'question', 'rackham', 'metric', 'cumque', 'deduplication', 'wework', 'appetite', 'aute', 'developed', 'shared', 'acquired', 'heard', '1983', 'struggle', 'ones', 'precursor', 'ab', 'vienna', 'fellowsturntotechdevcodecamplighthouse', 'amounts', 'worse', 'cleaningedit', '24', 'accompanying', 'nistsematech', 'extremes', 'malorum', 'accompanied', 'beaches', 'values', 'ibm', 'catch', 'excite', 'sections', 'austria', 'laborious', 'dichotomous', 'caught', 'classical', 'dojothinkfulnyc', 'bootcampsflatiron', 'stuck', 'order', 'carbohydrates', 'limits', 'iwas', 'parents', 'changed', 'ca', 'interview', 'loves', 'workshop', 'continuehey', 'linkpage', 'independent', 'states', 'coding', 'newswebinar', 'questions25', 'process', 'css', 'techniques20', 'finance', 'gives', 'totam', 'graphics', 'delineate', 'industrys', 'phase28', 'products', 'hererelated', 'provides', 'readily', 'technician', 'verifyreviewdatareviewtostring', '1984', 'methodsedit', 'reliability', 'insight', 'trust', 'regarded', 'share', 'door', 'earlier', 'g', 'goals', 'missing', 'phone', 'minimum', 'recursion', 'othersuse', 'marta', 'devoverall', 'arent', 'intelligence', 'office', 'teaches', 'peguero', 'reproducible', 'summary', 'morgan', 'taken', '91248', 'histograms', '2023', 'arrondissement', 'thriving', 'peers', 'articletalk', 'wanting', 'study', 'shape', 'simply', 'centuries', 'try', 'covers', 'spending', 'marketable', 'lighting', 'assistants', 'templatedata_visualization', 'donating', 'inappropriateironhackvery', 'jovanovich', 'cahiers', 'googletagdisplaydivgptad14745377621222', 'convert', 'completes', 'parseintscreeny', 'movie', 'told', 'topbottom', 'variations', 'velit', 'talked', 'fake', 'academylevelgeneral', 'pauloironhackironhackavg', 'identified', 'layer', 'relates', '24week', 'eye', 'linkedinfrom', 'characterize', 'logically',  ...

# %% [markdown]
# Do you see any problem in the output? How do you improve the output?
#
# A good way to improve your codes is to look into the HTML data sources and try to understand where the messy output came from. A good data analyst always learns about the data in depth in order to perform the job well.
#
# Spend 20-30 minutes to improve your functions or until you feel you are good at string operations. This lab is just a practice so you don't need to stress yourself out. If you feel you've practiced enough you can stop and move on the next challenge question.
